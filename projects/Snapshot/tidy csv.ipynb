# %%
import pandas as pd
import os

# %%
df = pd.read_csv("Snapshot.csv")
df.rename(columns={df.columns[0]: 'patients'}, inplace=True)
df
# Out:
#      patients  Sex (1=M, 2=F)  Age (years)  SDMT
# 0        9001               2           35    35
# 1        9003               2           53    56
# 2        9004               2           52    54
# 3        9005               1           37    31
# 4        9006               2           39    38
# ..        ...             ...          ...   ...
# 121      9270               1           48    25
# 122      9278               2           33    63
# 123      9279               2           55    65
# 124      9286               1           37    49
# 125      9287               1           53    55
#
# [126 rows x 4 columns]

# %%
file_list = [f.split('_')[0] for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]
int_list = [int(item) for item in file_list]

df['patients'].tolist()
matched_list1 = [item for item in df['patients'].tolist() if item in int_list]
matched_list1
# Out:
# [9001,
#  9003,
#  9004,
#  9005,
#  9006,
#  9007,
#  9008,
#  9009,
#  9016,
#  9018,
#  9019,
#  9020,
#  9022,
#  9028,
#  9029,
#  9031,
#  9036,
#  9038,
#  9039,
#  9042,
#  9043,
#  9046,
#  9048,
#  9051,
#  9058,
#  9062,
#  9067,
#  9098,
#  9101,
#  9109,
#  9115,
#  9116,
#  9118,
#  9132,
#  9136,
#  9158,
#  9163,
#  9168,
#  9169,
#  9172,
#  9177,
#  9180,
#  9181]

# %%
directory_path = "/home/yw4196/Snapshot_brain_nii"
file_paths = []
for f in os.listdir(directory_path):
    if os.path.isfile(os.path.join(directory_path, f)):
        item = f.split('_')[0]
        if int(item) in df['patients'].tolist():
            file_paths.append(os.path.join(directory_path,f))
df1 = df[df['patients'].isin(matched_list1)]
sorted_list = natsorted(file_paths)
df1['images'] = sorted_list

df1
# Out:
# /tmp/ipykernel_32691/2676571927.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['images'] = sorted_list
#     patients  Sex (1=M, 2=F)  Age (years)  SDMT  \
# 0       9001               2           35    35
# 1       9003               2           53    56
# 2       9004               2           52    54
# 3       9005               1           37    31
# 4       9006               2           39    38
# 5       9007               2           54    50
# 6       9008               2           48    52
# 7       9009               2           50    23
# 8       9016               2           54    69
# 9       9018               2           56    62
# 10      9019               2           34    66
# ...

# %%
df1.to_csv("Snapshot_tidy_brain.csv", index = False)
